# %% [markdown]
# # 📝 Introducción general
#
# Para este análisis utilicé un dataset bastante conocido de **Kaggle** llamado **Superstore**, que contiene información sobre las ventas de una tienda ficticia.
#
# Es un dataset muy popular para practicar análisis de datos por la cantidad de variables interesantes que tiene  ya que permite explorar distintos aspectos del comportamiento comercial.
#
# ---
#
# ##  ¿Qué información contiene el dataset?
#
# - **Order ID**: Identificador único de cada pedido
# - **Order Date**: Fecha en la que se realizó el pedido
# - **Ship Date**: Fecha en la que fue enviado el pedido
# - **Ship Mode**: Método de envío seleccionado (estándar, exprés, etc.)
# - **Customer ID**: ID único de cada cliente
# - **Customer Name**: Nombre del cliente
# - **Segment**: Tipo de cliente (consumidor, corporativo o home office)
# - **City**: Ciudad de destino
# - **State**: Estado o región
# - **Product ID**: ID único de cada producto
# - **Category**: Categoría general del producto
# - **Sub-Category**: Subcategoría específica del producto
# - **Product Name**: Nombre del producto
# - **Sales**: Total gastado por el cliente en ese producto
# - **Quantity**: Número de unidades vendidas
# - **Discount**: Descuento aplicado
# - **Profit**: Ganancia neta generada
# - **Year**: Año del pedido
# - **Month**: Mes en número
# - **Month_Name**: Nombre del mes
# - **Shipping_Days**: Días entre pedido y envío
#
# ---
#
# #  Introducción específica
#
# El objetivo de este análisis es explorar los datos de ventas, ganancias y comportamiento de los clientes para encontrar patrones importantes que ayuden a tomar mejores decisiones estratégicas.
#
# Se crearon muchas gráficas para observar el rendimiento del negocio desde distintos ángulos, pero en este cuaderno se explican solo las más relevantes.
#
# ---
#
# #  Preguntas clave que guiaron el análisis
#
# -  ¿Existen clientes que gastan mucho pero generan poca o ninguna ganancia?
# -  ¿Qué métodos de envío son más rentables y cuáles tardan más?
# -  ¿Qué relación hay entre aplicar descuentos y las ganancias?
# -  ¿Qué ciudades generan más ganancias?
# -  ¿Cuáles son los productos menos rentables?
# -  ¿Cómo ha variado la rentabilidad a lo largo del tiempo?

# %% [markdown]
# # Clientes que gastan mucho pero generan pocas ganancias
# En esta sección se analiza si hay clientes que realizan compras de alto valor pero que no dejan ganancias para la empresa. Esto puede indicar promociones mal aplicadas o problemas en márgenes de productos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 📉 Clientes con alto gasto y ganancias negativas
#
# En esta gráfica se muestran los clientes que, entre **2014 y 2017**, han gastado sumas bastante altas, pero que en lugar de generar ganancias, han terminado generando **pérdidas para la empresa**.
#
# Por ejemplo, hay un caso extremo donde el cliente llamado **Grant Thornton** con ID `GT:14632` ha gastado más de \$9,300, pero la ganancia fue de **−\$4,000**. Esto es preocupante porque:
#
# - La empresa no solo no ganó nada, sino que además absorbió **casi la mitad del costo de la venta**.
# - Es prácticamente como si se le hubiera hecho un **descuento del 40% o más**, pero **sin que estuviera planeado como parte de una estrategia**.
#
# **Estos casos son  una señal de alerta** y valdría la pena analizarlos con más detalle.
# Podría ser útil revisar **qué tipo de productos compran**, **qué descuentos se les aplican**, o si pertenecen a **algún segmento en particular**.
# También puede haber problemas con los **márgenes de ciertos productos** o con **políticas de descuento poco sostenibles**.

# %% [markdown]
# # Añalisis con  más detalle  del  caso  más grave
#
# ** Se identificó un caso particular**
#
# Cliente ID: GT-14635
# Total gastado: \$9,351
# Ganancia generada: \-$4,187.11
#
# #Análisis de  sus  compras
# Se filtraron las compras que  generaron profit negativo de este cliente para entender mejor qué productos adquirió, qué descuentos se le aplicaron y cuánto profit generó cada compra:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🔍 Observaciones
#
# Ambos productos fueron vendidos con descuentos agresivos (40% y 50%).
#
# El producto más costoso generó una pérdida de casi el 50% del valor de la venta.
#
# Este patrón sugiere que las políticas de descuento pueden estar afectando fuertemente la rentabilidad
#
#
# ##Posibles soluciones
# -**Los descuentos mal aplicados pueden anular por completo la rentabilidad**, estos productos ** no**  deberían de tener descuento
#
# -**Ajustar las promociones según rentabilidad**: En lugar de enfocarse solo en vender más, se podrían diseñar promociones que favorezcan los productos con mejor margen de ganancia.
#
# -**Agregar alertas internas**: Un sistema que avise si una venta tiene demasiado descuento en relación al costo podría ser útil para revisar antes de confirmar la transacción.

# %% [markdown]
# # 🚚 ¿Cómo afecta el tipo de envío a las ganancias?
# Analicé los distintos métodos de envío disponibles en la tienda y su impacto en dos variables clave:
#
# **Tiempo promedio de entrega**
#
# **Ganancia total generada (Profit)**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🔍 Observaciones
#
#  **Same Day**  entrega casi al instante (en menos de un día), pero genera muy poca ganancia. Es el más rápido, pero también el menos rentable.
#
# **Standard Class** aunque es el más lento, genera la mayor parte de las ganancias del negocio. Probablemente porque es el más usado y tiene costos más bajos.
#
# **First y Second Class** tienen un equilibrio entre tiempo y rentabilidad, pero siguen muy por debajo de Standard en ganancias.
#
# # Posibles soluciones
#
# ## Primera solución
#
# **Revisar el modelo de Same Day** : Si entregar el mismo día cuesta mucho y no deja ganancia, se podría aumentar el precio de ese servicio o limitarlo solo a ciertos productos o clientes premium.
#
# ### Ideas para mejorar el envío Same Day
# Al ver que el envío "Same Day" (mismo día) genera poca ganancia a pesar de ser el más rápido, se me ocurren algunas formas en las que la tienda podría ajustar su estrategia sin tener que eliminar esta opción por completo:
#
#  **Ofrecer Same Day solo para ciertos productos**
#
# -No todos los productos tienen sentido para entregar tan rápido. Por ejemplo, enviar un escritorio gigante en el mismo día puede ser muy diicl logísticamente y no dejar nada de ganancia. En cambio, podrían aplicar esta opción solo a productos más pequeños o fáciles de mover, como accesorios de oficina o tecnología liviana. Así se simplifica la operación y se evita perder dinero con cada entrega.
#
# **Limitar Same Day a zonas específicas**
#
# -Este tipo de envíos tiene más sentido en ciudades grandes o lugares cerca del centro de distribución.  La tienda podría restringir esta opción a ciertas regiones donde sea más eficiente y rentable hacerlo.
#
#  **Convertirlo en un beneficio premium**
#
# -En lugar de ofrecer Same Day a todos, podrían dejarlo solo para clientes que formen parte de algún programa especial o que compren frecuentemente. Esto lo haría ver como un servicio exclusivo, y al mismo tiempo limitaría su uso a personas que realmente aportan valor al negocio.
#
# ## Segunda solución
#
# **Mejorar Standard Class**: Dado que ya es el más rentable, podrían usar los recursos que hoy están en Same Day para acelerar un poco el tiempo de entrega de Standard Class. Así, se vuelve más atractivo sin afectar la ganancia.
#
# ###Ideas para mejorar el envío  en  Standar Class
#
# **Reasignar  algunos recursos de Same Day a Standard Class**
#
# Si Same Day está usando recursos (como transporte rápido o personal extra) pero no deja mucha ganancia, tiene más sentido usar esa logística para fortalecer el envío Standard. Por ejemplo,  se podrían reforzar rutas, mejorar tiempos de preparación o hacer entregas más eficientes sin aumentar los costos, aprovechando lo que ya se tiene, reduciendo así el tiempo promedio  de entrega con el objetivo de que el cliente sienta que llega "más pronto de lo esperado", lo cual mejoraría la experiencia  del  mismo

# %% [markdown]
# # 💬 Análisis del impacto de los descuentos
# En esta parte  me puse a ver cómo los descuentos afectan las ganancias de la tienda. Lo que hice fue juntar las ventas por porcentaje de descuento y sacar el profit promedio de cada grupo. Así pude darme cuenta si algunos descuentos ayudaban a generar mas ganancia  o si al final terminaban perjudicando el negocio.
# ![image.png](data:image/png;base64,...)
#
#
#
# # 🔍 Observaciones
# -En primer lugar, me pareció curioso que cuando no hay descuento, la tienda gana en promedio unos     \$66 por venta, pero cuando se aplica un 10% de descuento, la ganancia sube a \$96. Esto sugiere que un descuento pequeño no solo incentiva las ventas, sino que mejora la rentabilidad.
#
# -Sin embargo, a partir de aproximadamente un 25% de descuento, el promedio de ganancias se vuelve negativo. Es decir, la tienda empieza a perder dinero con cada venta.
#
# -La pérdida más alta se da con el 50% de descuento, donde el promedio de pérdida por venta supera los $300.
#
# **Posibles soluciones**
# -Guardar los descuentos altos (como 50%) solo para productos puntuales o promos muy pensadas, para no perjudicar las ganancias.
#
# -Evaluar si descuentos moderados (como el 10% o 15%) pueden seguir aplicándose de forma más amplia, ya que parecen ser beneficiosos

# %% [markdown]
# # Análisis por ciudad  para saber donde  se gana mas
# Quise saber en qué ciudades la tienda obtiene más ganancias, así que agrupé los datos por ciudad y sumé el profit total de cada una. Luego ordené los resultados y me quedé con las 6 ciudades más rentables.
#
# No es que la tienda tenga sucursales con diferentes catálogos. El dataset representa una única tienda que envía a todo Estados Unidos, así que los clientes simplemente hacen pedidos desde su ciudad.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🔍 Observaciones
# **New York City** lidera ampliamente, con más de \$62,000 (38.2%) en ganancias totales. Le sigue **Los Angeles** con un poco más de \$30,000 (18.8%) y luego **Seattle**, **San Francisco**,** Detroit** y **Lafayette**.
#
# Lo interesante es que hay una gran diferencia entre la primera ciudad y el resto. Por ejemplo, **Nueva York genera el doble que Los Ángeles**, **y más de seis veces lo que se gana en Lafayette.**
#
# Ahora bien, como todas las ciudades tienen las mismas condiciones de venta (precios, productos, descuentos, etc.), lo que probablemente está marcando la diferencia no es algo interno de la tienda, sino algo externo como  por ejemplo la presencia que tiene la marca en esas ciudades.
#
# Una posible explicación es que en ciudades como Nueva York ya los conocen más, quizás por campañas anteriores, boca a boca, o simplemente porque hay más usuarios fieles. Mientras tanto en ciudades menos rentables como Lafayette, puede que la tienda no sea tan conocida, o la gente no tenga tanto incentivo para comprar.
#
#
# ## Posibles soluciones
#
# -**Impulsar el marketing en ciudades menos rentables**  por ejemplo con campañas locales o promociones exclusivas con el objetivo de hacer la tienda más conocida,  es decir ganar popularidad.
#
# -**Escuchar a los clientes de todas las zonas**: No solo a los que generan mucha ganancia (como en Nueva York), sino también a los que casi no la generan. Así se podría identificar lo  que  se está haciendo bien en unas zonas (para repetirlo) y lo que se  podría mejorar en otras (para corregirlo)

# %% [markdown]
# # Análisis de productos que generan más pérdidas
# En esta parte  me enfoqué en identificar los productos que han generado mayores pérdidas para la tienda. Para eso agrupé por nombre del producto y sumé el profit total asociado a cada uno ordenándolos de menor a mayor. El resultado es  que muestra los 10 productos con las mayores pérdidas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🔍 Observaciones
#
# "El producto **con mayores pérdidas** fue la Cubify CubeX 3D Printer Double Head Print, con un profit negativo de casi \$9,000. Le siguen modelos similares, como la versión Triple Head, e impresoras de gama alta como la Lexmark MX611dhe.
#
# ** Estos artículos comparten dos características**: son tecnología avanzada o equipos de oficina premium.
#
# ## Posibles soluciones
#
# -**El patrón sugiere que estos productos podrían estar generando pérdidas por su alto costo o por cómo se están vendiendo**. Hay que revisar si realmente están resultando muy costosos de adquirir o si hay algún otro factor, como descuentos aplicados  que estén afectando su rentabilidad.
#
# -**Ofrecer estos productos solo bajo demanda o a clientes específicos**: En lugar de mantener inventario o promoverlos ampliamente, podrían ofrecerse solo bajo pedido o para clientes premium, donde se pueda justificar mejor el precio y el costo logístico.

# %% [markdown]
# #Análisis de las ganancias anuales
# Para este análisis, revisé las ventas y las ganancias totales por año, además de calcular el margen de ganancia  entre 2014 y 2017.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🔍 Observaciones
# -En general, las ventas han ido creciendo cada año, lo cual en teoría es una buena señal.
#
# -El margen de ganancia también aumentó del 2014 al 2016, pasando de un 10.2% a un 13.4%, pero en 2017, aunque fue el año con más ventas, el margen bajó a 12.7%.
# Eso llama la atención, porque uno esperaría que más ventas signifiquen más ganancias
#
# ## Posibles soluciones
# Puede que ese aumento en ventas venga de productos que dejan poca ganancia o de muchas ofertas que terminan bajando la rentabilidad. Por eso valdría la pena revisar qué se vendió en 2017 ¿fueron productos con bajo margen? ¿hubo más descuentos que en otros años? eso podría dar pistas de por qué se vendió tanto pero se ganó menos y así ver cómo mejorar la estrategia para los próximos años.
